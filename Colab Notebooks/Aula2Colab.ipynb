# %%
print = ('Minha	primeira	aplicação	Python!')
# Out:
#   File "<ipython-input-5-32f3da9c02e6>", line 1
#     print = (Minha	primeira	aplicação	Python!)
#                   	       ^
# SyntaxError: invalid syntax
