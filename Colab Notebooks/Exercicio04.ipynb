# %%
A = 'A'
print(A)
# Out:
# A

# %%
p = 6
if (p > 5):
    print('p é maior')
else:
    print('p é menor')
# Out:
# p é maior

# %%
p = 4
if (p > 5):
    print('p é maior')
else:
    print('p é menor')
# Out:
# p é menor

# %%
p = 5
if (p > 5):
    print('p é maior')
else:
    print('p é menor')
# Out:
# p é menor

# %%
# Out:
# p é maior
