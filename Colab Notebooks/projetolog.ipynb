# %%
print('-' * 42)
print('Bem vindo ao nosso programa de cálculos')
print('-' * 42)

print('Vamos começar com seu cadastro, nos informe qual seu nome \n')
name = str(input('Digite seu nome:'))
print()

while (len(name) <= 3):
    print('Digite um nome com mais de 3 caracteres')
    name = str(input("Infrome um nome: "))
    print()

print('Nos informe seu sexo: \n')

sexo = str(input("Informe a inicial do seu [F/M]: "))
print()

while sexo != "f" and sexo != 'F' and sexo != "m" and sexo != 'M':
    print('Informe um sexo válido, com apenas a inicial')
    sexo = str(input("Informe a inicial do seu sexo: "))
    print()

print('Nos informe sua idade: \n')

idade = int(input('Digite sua idade: '))

while (idade > 150 or idade < 0):
    print('Informe uma idade válida:')
    idade = int(input("Informe a idade: "))
    print()
print('Seu nome é', name, 'você tem', idade, 'anos, seu sexo é:', sexo)

confirm = str(input('Suas informações estão certas ? [Sim/Não]: '))
print()

if (confirm == 'Não' or confirm == 'não' or confirm == 'nao' or confirm == 'Nao'):

    print('Preencha suas informações novamente \n')

    print('-' * 42)
    print('Bem vindo ao nosso programa de cálculos !')
    print('-' * 42)

    print('Vamos começar com seu cadastro, nos informe qual seu nome \n')
    name = str(input('Digite seu nome: '))
    print()

    while (len(name) <= 3):
        print('Digite um nome com mais de 3 caracteres')
        name = str(input("Informe um nome: "))
        print()

    print('Nos informe seu sexo: \n')

    sexo = str(input("Informe a inicial do seu sexo [F/M]: "))
    print()

    while sexo != "f" and sexo != 'F' and sexo != "m" and sexo != 'M':
        print('Informe um sexo válido, com apenas a inicial')
        sexo = str(input("Informe a inicial do seu sexo: "))
        print()

    print('Nos informe sua idade: \n')

    idade = int(input('Digite sua idade: '))

    while (idade > 150 or idade < 0):
        print('Informe uma idade válida:')
        idade = int(input("Informe a idade: "))
        print()
    print('Seu nome é', name, 'você tem', idade, 'anos, seu sexo é:', sexo)
# Out:
# ------------------------------------------
# Bem vindo ao nosso programa de cálculos
# ------------------------------------------
# Vamos começar com seu cadastro, nos informe qual seu nome
#
# Digite seu nome:joão
#
# Nos informe seu sexo:
#
# Informe a inicial do seu [F/M]: m
#
# Nos informe sua idade:
#
# Digite sua idade: 157
# Informe uma idade válida:
# Informe a idade: 1
#
# Seu nome é joão você tem 1 anos, seu sexo é: m
# Suas informações estão certas ? [Sim/Não]: sim

# %%
def dois_soma(n1=0, n2=0):
    n1 = int(input('1° Número: '))
    n2 = int(input('2° Número: '))
    soma = n1 + n2
    print(soma)


def dois_subtração():
    n1 = int(input('1° Número: '))
    n2 = int(input('2° Número: '))
    sub = n1 - n2
    print(sub)


def dois_dividir():
    n1 = int(input('1° Número: '))
    n2 = int(input('2° Número: '))
    div = n1 / n2
    print(div)


def dois_multiplicar():
    n1 = int(input('1° Número: '))
    n2 = int(input('2° Número: '))
    mult = n1 * n2
    print(mult)


def dois_exponenciação():
    n1 = int(input('1° Número: '))
    n2 = int(input('2° Número: '))
    exp = n1 ** n2
    print(exp)


def main():
    while True:
        print('-' * 20)
        print('Menu de cálculo')
        print('-' * 20)
        print()
        print('opções: ')
        print('[1] Somar')
        print('[2] Subtrair')
        print('[3] Dividir')
        print('[4] Multiplicar')
        print('[5] Exponenciação')
        print('[6] Encerrar programa')

      resp = int(input('Sua opção: '))

      if resp == 1:
          dois_soma()
      elif resp == 2:
          dois_subtração
      elif resp == 3:
          dois_dividir
      elif resp == 4:
          dois_multiplicar
      elif resp == 5:
          dois_exponenciação
      elif resp == 6:
          print('Você optou por sair do programa.')
      else:
          print('Opção inválida')
main()
