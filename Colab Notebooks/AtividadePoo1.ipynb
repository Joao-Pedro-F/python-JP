# %%
#3
def sum(num1, num2):
    return num1 + num2
        
print("\tSoma de dois números\n")
num1 = int(input("Digite um número: "))
num2 = int(input("Digite outro número: "))

print ("")
print ("O resultado da soma é %d" %sum(num1, num2))
# Out:
# 	Soma de dois números
#
# Digite um número: 5
# Digite outro número: 2
#
# O resultado da soma é 7

# %%
#4

var1 = input('escreva algo ')
print('o tipo primitivo desse valor é ', type(var1))
print('só tem espaços? ', var1.isspace())
print('é um número? ', var1.isnumeric())
print('é alfabético? ', var1.isalpha())
print('é alfanumérico? ', var1.isalnum())
print('está em maiúsculas? ', var1.isupper())
print('esta é minúsculas? ', var1.islower())
print('está capitalizada? ', var1.istitle())
# Out:
# escreva algo 10
# o tipo primitivo desse valor é  <class 'str'>
# só tem espaços?  False
# é um número?  True
# é alfabético?  False
# é alfanumérico?  True
# está em maiúsculas?  False
# esta é minúsculas?  False
# está capitalizada?  False

# %%
#5

numint = int(input('digite um número'))
print('analisando o número {}, o número sucessor é {} e o antecessor é {}'.format(numint, (numint+1), (numint-1)))
# Out:
# digite um número1
# analisando o número 1, o número sucessor é 2 e o antecessor é 0

# %%
#6

n = int(input('digite um número'))
print('o dobro do número é {}, \n o triplo é {} \n e a raiz quadrada é {:.2f}'.format((n*2), (n*3), (n**(1/2))))
# Out:
# digite um número2
# o dobro do número é 4,
#  o triplo é 6
#  e a raiz quadrada é 1.41

# %%
#7
nota1 = float(input('Primeira nota: '))
nota2 = float(input('Segunda nota: '))

media = (nota1+nota2) / 2

print('Media: ',media)
    
if media<7.0:
      print('Reprovado')
elif media<10:
      print('Aprovado')
else:
      print('Aprovado com Distinção!')
# Out:
# Primeira nota: 410
# Segunda nota: 10
# Media:  210.0
# Aprovado com Distinção!

# %%
#8

print("\tConversão de Metros para Milímetros\n")

metros = float(input("Metros: "))

milimetros = (metros * 1000)

print("")
print("Conversão em milímetros: %6.2f" %milimetros)
# Out:
# 	Conversão de Metros para Milímetros
#
# Metros: 2
#
# Conversão em milímetros: 2000.00

# %%
#9

num = int(input('Digite um numero para ver a sua tabuada: '))

print(num, 'x 0  = ', num * 0)
print(num, 'x 1  = ',num * 1)
print(num, 'x 2  = ',num * 2)
print(num, 'x 3  = ',num * 3)
print(num, 'x 4  = ',num * 4)
print(num, 'x 5  = ',num * 5)
print(num, 'x 6  = ',num * 6)
print(num, 'x 7  = ',num * 7)
print(num, 'x 8  = ',num * 8)
print(num, 'x 9  = ',num * 9)
print(num, 'x 10  = ',num * 10)
# Out:
# Digite um numero para ver a sua tabuada: 10
# 10 x 0  =  0
# 10 x 1  =  10
# 10 x 2  =  20
# 10 x 3  =  30
# 10 x 4  =  40
# 10 x 5  =  50
# 10 x 6  =  60
# 10 x 7  =  70
# 10 x 8  =  80
# 10 x 9  =  90
# 10 x 10  =  100

# %%
#10

print('{:=^25}'.format(' CT VIRTUAL '))
print('{:=>20}'.format('== US1.00 == R$3.27 =='))
ct = float(input('Informe o valor que tu tem na carteira: '))
print('Com R${:.2f} reais posso comprar US{:.2f} dolares.'.format(ct, ct/3.27))
# Out:
# ====== CT VIRTUAL =======
# == US1.00 == R$3.27 ==
# Informe o valor que tu tem na carteira: 1.00
# Com R$1.00 reais posso comprar US0.31 dolares.

# %%
#11

altura = float(input('Digite a alturada parede: '))

largura = float(input('Digite a largura da parede: '))

area = altura * largura

tinta = area / 2

print('Para pintar uma area de {} é necessario {} litros de tinta'.format(area,tinta))

# %%
#12

preço = float(input("Digite o preço da mercadoria:"))
desconto = float(input("Digite o percentual de desconto:"))
valor_do_desconto = preço * desconto / 100
a_pagar = preço - valor_do_desconto
print("Um desconto de %5.2f %% em uma mercadoria de R$ %7.2f" % (desconto, preço))
print("vale R$ %7.2f." % valor_do_desconto)
print("O valor a pagar é de R$ %7.2f" % a_pagar)
# Out:
# Digite o preço da mercadoria:46
# Digite o percentual de desconto:41
# Um desconto de 41.00 % em uma mercadoria de R$   46.00
# vale R$   18.86.
# O valor a pagar é de R$   27.14

# %%
salário = float(input("Digite o salário atual:"))
p_aumento = float(input("Digite a porcentagem de aumento:"))
aumento = salário * p_aumento / 100
novo_salário = salário + aumento
print("Um aumento de %5.2f %% em um salário de R$ %7.2f" % (p_aumento, salário))
print("é igual a um aumento de R$ %7.2f" % aumento)
print("Resultando em um novo salário de R$ %7.2f" % novo_salário)
# Out:
# Digite o salário atual:230
# Digite a porcentagem de aumento:15
# Um aumento de 15.00 % em um salário de R$  230.00
# é igual a um aumento de R$   34.50
# Resultando em um novo salário de R$  264.50
