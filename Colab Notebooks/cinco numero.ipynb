# %%
num = [0, 0, 0, 0, 0]
ind = 0
print('Populando uma lista. \n')
while ind < 5:
 num[ind] = int(input("Número :"))
 ind+=1
# Out:
# Populando uma lista.
#
# Número :1
# Número :5
# Número :7
# Número :8
# Número :56
