# %%
#14

C = float(input("Digite a temperatura em °C:"))
F = (9 * C / 5) + 32
print("%5.2f°C é igual a %5.2f°F" % (C, F))
# Out:
# Digite a temperatura em °C:30
# 30.00°C é igual a 86.00°F

# %%
#15

km = float(input('Quantos km foram percorridos: '))
dias = int(input('Quantos dias foram o aluguel: '))
valorKmPercorrido = km * 0.15
valorDiaAluguel = 60 * dias

print(f' O valor total foi R${valorKmPercorrido + valorDiaAluguel}, sendo R${valorKmPercorrido} ao km percorrido e R${valorDiaAluguel} aos dias de aluguel')
# Out:
# Quantos km foram percorridos: 30
# Quantos dias foram o aluguel: 2
#  O valor total foi R$124.5, sendo R$4.5 ao km percorrido e R$120 aos dias de aluguel

# %%
#16

n1 = int(input('digite um número: '))
n2 = int(input('digite outro número: '))
soma = n1+n2
print('a soma entre {} e {} é igual a {}'.format(n1, n2, soma))
# Out:
# digite um número: 20
# digite outro número: 40
# a soma entre 20 e 40 é igual a 60

# %%
#17

from math import hypot 

co = float(input('Comprimento do cateto oposto :'))
ca = float(input('Comprimento do cateto adjacente: '))
hi = hypot(co, ca)

print('A hipotenusa vai medir {:.2f}'.format(hi))
# Out:
# Comprimento do cateto oposto :20
# Comprimento do cateto adjacente: 4
# A hipotenusa vai medir 20.40

# %%
<img src

# %%
#18

from math import sin, cos, tan, radians

ang = float(input("Digite um ângulo de uma circunferência (ou seja, entre 0º e 360º): \n"))

seno = sin(radians(ang))
coss = cos(radians(ang))
tang = tan(radians(ang))

print("O ângulo de {} tem o seno de {:.2f}.".format(ang, seno))
print("O ângulo de {} tem o cosseno de {:.2f}.".format(ang, coss))
print("O ângulo de {} tem a tangente de {:.2f}.".format(ang, tang))
# Out:
# Digite um ângulo de uma circunferência (ou seja, entre 0º e 360º):
# 87
# O ângulo de 87.0 tem o seno de 1.00.
# O ângulo de 87.0 tem o cosseno de 0.05.
# O ângulo de 87.0 tem a tangente de 19.08.

# %%
#19

from random import choice
a1 = input('Nome da(o) primeira(o) aluna(o): ')
a2 = input('Nome da(o) segunda(o) aluna(o): ')
a3 = input('Nome da(o) terceira(o) aluna(o); ')
a4 = input('Nome da(o) quarta(o) aluna(o): ')
lista = [a1, a2, a3, a4]
#escolhida = random.choice(lista)
escolhida = choice(lista)
print('A aluna sorteada foi {}!'.format(escolhida))
# Out:
# Nome da(o) primeira(o) aluna(o): joao
# Nome da(o) segunda(o) aluna(o): pedro
# Nome da(o) terceira(o) aluna(o); natan
# Nome da(o) quarta(o) aluna(o): miro
# A aluna sorteada foi pedro!

# %%
#20

import random

nome1 = str(input('  Digite o primeiro nome:     '))
nome2 = str(input('  Digiteo segundo nome:     '))
nome3 = str(input('  Digite o terceiro nome:     '))
nome4 = str(input('  Digite o quarto nome:     '))

lista = [nome1,nome2,nome3,nome4]

random.shuffle(lista)

print(lista)
# Out:
#   Digite o primeiro nome:     NATAN É GAY
#   Digiteo segundo nome:     JOAO É FÃS

# %%
#21

'''import pygame

pygame.init()
pygame.mixer.music.load('aha.mp3')
pygame.mixer.music.play()
pygame.event.wait()'''

# %%
#22

nome = str(input("\nDigite seu nome e sobrenome: ")).strip()
dividido = nome.split()
print('\nO seu nome com todas as letras maiusculas ficará: {}'.format(nome.upper()))
print('\nEm minusculas: {}'.format(nome.lower()))
print('\nA quantidade de letras é: {}'.format(len(nome) - nome.count(' ')))
print('\nE a quantidade de letras do seu primeiro nome é de: {}'.format(len(dividido[0])))
# Out:
# Digite seu nome e sobrenome: gdkgldg knlakdgnal kgnaldkngas
#
# O seu nome com todas as letras maiusculas ficará: GDKGLDG KNLAKDGNAL KGNALDKNGAS
#
# Em minusculas: gdkgldg knlakdgnal kgnaldkngas
#
# A quantidade de letras é: 28
#
# E a quantidade de letras do seu primeiro nome é de: 7

# %%
#23

print('DESAFIO 23')
print('Faça um programa que leia um número de 0 a 9999 e mostre na tela cada um dos digitos separados')

num = str(input('Digite um número de 0 a 9999: ')).zfill(4)

print('\nO número digitado foi: {}'.format(num))
print('Sua unidade é: {}'.format(num[3]))
print('Sua dezena é: {}'.format(num[2]))
print('Sua centena é: {}'.format(num[1]))
print('seu milhar é: {}'.format(num[0]))
# Out:
# DESAFIO 23
# Faça um programa que leia um número de 0 a 9999 e mostre na tela cada um dos digitos separados
# Digite um número de 0 a 9999: 2045
#
# O número digitado foi: 2045
# Sua unidade é: 5
# Sua dezena é: 4
# Sua centena é: 0
# seu milhar é: 2

# %%
#24

print('=====DESAFIO 24=====')
print('Crie um programa que leia o nome de uma cidade e diga se ela começa ou não com santo')

cidade = str(input('Digite o nome de sua cidade: ')).strip().lower().capitalize()

print('Santo' in cidade[:5])
# Out:
# =====DESAFIO 24=====
# Crie um programa que leia o nome de uma cidade e diga se ela começa ou não com santo
# Digite o nome de sua cidade: santo
# True
